# %% [markdown]
# # Split text

# %%
from docx import Document

# %%
# read document
doc_name = 'doc2.docx'

doc = Document(doc_name)

# %%
# defining the paragraphs
# and make the dict, whre key ....... FUCKKKKKK is name of paragraph (heading), value is the corresponding text

heading_len = 100 # need to determine the optimal

paragraphs = doc.paragraphs
doc_res = dict()

for i, par in enumerate(paragraphs):
    # add preprocessing
    # ...
    
    # remove empty strings
    # ...
    
    # case, where list of items
    # ...
    
    # tables, figures, etc.
    # ...
    
    # title page (need special flag or something)
    # ...
    
    if (len(par.text) < heading_len) and (i+1 != len(paragraphs)):
        doc_res[i] = {'Heading': par.text, 'Text': paragraphs[i+1].text}

# %%
doc_res
# Out:
# {0: {'Heading': 'Министерство науки и высшего образования Российской Федерации',
#   'Text': 'ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЫСШЕГО ОБРАЗОВАНИЯ'},
#  1: {'Heading': 'ФЕДЕРАЛЬНОЕ ГОСУДАРСТВЕННОЕ АВТОНОМНОЕ ОБРАЗОВАТЕЛЬНОЕ УЧРЕЖДЕНИЕ ВЫСШЕГО ОБРАЗОВАНИЯ',
#   'Text': '«НАЦИОНАЛЬНЫЙ ИССЛЕДОВАТЕЛЬСКИЙ УНИВЕРСИТЕТ ИТМО»'},
#  2: {'Heading': '«НАЦИОНАЛЬНЫЙ ИССЛЕДОВАТЕЛЬСКИЙ УНИВЕРСИТЕТ ИТМО»',
#   'Text': '(Университет ИТМО)'},
#  3: {'Heading': '(Университет ИТМО)', 'Text': ''},
#  4: {'Heading': '',
#   'Text': 'Факультет программной инженерии и компьютерной техники'},
#  5: {'Heading': 'Факультет программной инженерии и компьютерной техники',
#   'Text': 'Образовательная программа: Программная инженерия'},
#  6: {'Heading': 'Образовательная программа: Программная инженерия',
#   'Text': ''},
#  7: {'Heading': '',
#   'Text': 'Направление подготовки (специальность): Системное и прикладное программное обеспечение'},
# ...

# %%
# save final file
doc_res.save('result.txt') # format
